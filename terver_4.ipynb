# %% [markdown]
# ##### Task 1, 2

# %% [markdown]
# ![photo_2019-07-03_16-02-03.jpg](attachment:photo_2019-07-03_16-02-03.jpg)

# %% [markdown]
# ##### Task 3

# %%
import numpy as np

# %%
def norm(x, M, sigma):
    return (x - M) / sigma

# %%
M = 174
sigma = 8

# %% [markdown]
# <182

# %%
norm(184, M, sigma)
# Out:
# 1.25

# %%
z1 = 0.10565
1 - z1
# Out:
# 0.89435

# %% [markdown]
# < 190

# %%
norm(190, M, sigma)
# Out:
# 2.0

# %%
z2 = 0.02275
1 - z2
# Out:
# 0.97725

# %% [markdown]
# 166 - 190

# %%
print(norm(166, M, sigma))
print(norm(190, M, sigma))
# Out:
# -1.0
# 2.0

# %%
(1 - z2) - 0.1587
# Out:
# 0.8185499999999999

# %% [markdown]
# 166 - 182

# %%
(1 - z1) - 0.1587
# Out:
# 0.7356499999999999

# %% [markdown]
# 158 - 190

# %%
print(norm(158, M, sigma))
# Out:
# -2.0

# %%
(1 - z2) - 0.0228
# Out:
# 0.9544499999999999

# %% [markdown]
# 150 - 190

# %%
print(norm(150, M, sigma))
# Out:
# -3.0

# %%
(1 - z2) - 0.0013
# Out:
# 0.97595

# %% [markdown]
# 150 - 198

# %%
print(norm(198, M, sigma))
print(norm(150, M, sigma))
# Out:
# 3.0
# -3.0

# %%
0.9987 - 0.0013
# Out:
# 0.9974000000000001

# %% [markdown]
# < 160

# %%
print(norm(166, M, sigma))
# Out:
# -1.0

# %%
0.1587
# Out:
# 0.1587

# %% [markdown]
# ##### Task 4

# %%
M = 178
D = 25

sigma = np.sqrt(D)

# %%
print(f'отклонение на {norm(190, M, sigma)} сигм')
# Out:
# отклонение на 2.4 сигм
